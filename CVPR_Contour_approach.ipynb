# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusBloise/AspnetCoreApp/blob/master/CVPR_Contour_approach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow


img_name = 'smpl_for_contour.png'
image_vec = cv2.imread(img_name, 1)
g_blurred = cv2.GaussianBlur(image_vec, (5, 5), 0)

# %%
blurred_float = g_blurred.astype(np.float32) / 255.0
edgeDetector = cv2.ximgproc.createStructuredEdgeDetection("model.yml.gz")
edges = edgeDetector.detectEdges(blurred_float) * 255.0
#cv2.imwrite('edge-raw.jpg', edges)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x7F3FB11A3110>
